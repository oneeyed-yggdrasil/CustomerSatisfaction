# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

# %%
data = pd.read_csv('/Users/aarthanarumugam/DC/Sem_1/Capstone/temp/final.csv')

# %%
data.head
# Out:
# <bound method NDFrame.head of       CustomerID  Gender  Senior_Citizen Partner Dependents  Tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#           Service_type    Multiple_Lines Internet_Service_type  \
# ...

# %%
df = data.sort_values('CustomerID',ascending=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of       CustomerID  Gender  Senior_Citizen Partner Dependents  Tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#           Service_type    Multiple_Lines Internet_Service_type  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CustomerID                         7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Senior_Citizen                     7043 non-null   int64
#  3   Partner                            7043 non-null   object
#  4   Dependents                         7043 non-null   object
#  5   Tenure                             7043 non-null   int64
#  6   Service_type                       7043 non-null   object
#  7   Multiple_Lines                     7043 non-null   object
#  8   Internet_Service_type              7043 non-null   object
#  9   Online_Security                    7043 non-null   object
#  10  Online_Backup                      7043 non-null   object
# ...

# %%
df['class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                           0
# Gender                               0
# Senior_Citizen                       0
# Partner                              0
# Dependents                           0
# Tenure                               0
# Service_type                         0
# Multiple_Lines                       0
# Internet_Service_type                0
# Online_Security                      0
# Online_Backup                        0
# Device_Protection                    0
# Tech_Support                         0
# Streaming_TV                         0
# Streaming_Movies                     0
# Contract                             0
# Paperless_Billing                    0
# Payment_Method                       0
# Monthly_Charges                      0
# Total_Charges                        0
# Number_of_Referrals                  0
# Offer                                0
# Avg_Monthly_Long_Distance_Charges    0
# Avg_Monthly_GB_Download              0
# ...

# %%
data = df.drop(['Churn','Senior_Citizen','Multiple_Lines','Online_Security','Online_Backup','Device_Protection','Tech_Support','Streaming_Movies','Paperless_Billing','Upgraded_to_Unlimited_Data'], axis=1)

target = df['Churn']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((4718, 18), (2325, 18))

# %%
data['Gender'] = data['Gender'].apply(
    lambda x: 1 if x == 'Male' else (0 if x == 'Female'))
# Out:
#   Cell In[32], line 2
#     lambda x: 1 if x == 'Male' else (0 if x == 'Female'))
#                                      ^
# SyntaxError: expected 'else' after 'if' expression

# %%
dat.head()
# Out:
#    CustomerID Gender Partner Dependents  Tenure   Service_type  \
# 0  0002-ORFBO   None     Yes        Yes       9  Phone Service
# 1  0003-MKNFE   None      No         No       9  Phone Service
# 2  0004-TLHLJ   None      No         No       4  Phone Service
# 3  0011-IGKFF   None     Yes         No      13  Phone Service
# 4  0013-EXCHZ   None     Yes         No       3  Phone Service
#
#    Internet_Service_type Streaming_TV        Contract    Payment_Method  \
# 0                    NaN          Yes        One Year      Mailed check
# 1                    NaN           No  Month-to-Month      Mailed check
# 2                    NaN           No  Month-to-Month  Electronic check
# 3                    NaN          Yes  Month-to-Month  Electronic check
# 4                    NaN          Yes  Month-to-Month      Mailed check
#
#    Monthly_Charges  Total_Charges  Number_of_Referrals    Offer  \
# 0             65.6         593.30                    2       No
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder as ce
# encode categorical variables with ordinal encoding

encoder = ce.OrdinalEncoder(cols=['Internet_Service_type'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
#       1 from sklearn.preprocessing import OrdinalEncoder as ce
#       2 # encode categorical variables with ordinal encoding
# ----> 4 encoder = ce.OrdinalEncoder(cols=['Internet_Service_type'])
#
# AttributeError: type object 'OrdinalEncoder' has no attribute 'OrdinalEncoder'

# %%
from sklearn.preprocessing import OrdinalEncoder

# Sample data with 
ordinal categoriesdata = [['low', 'hot'],
                          ['medium', 'cold'],
                          ['high', 'hot'],
                          ['low', 'cold']]

# Create an instance of OrdinalEncoderencoder = OrdinalEncoder()

# Fit the encoder to your data and transform the data

encoded_data = encoder.fit_transform(data)


# The transformed data will be a NumPy array

print(encoded_data)

# %%
X.Internet_Service_type = X.Internet_Service_type.map({'Cable' : 0, 'No' : 1, 'DSL' : 2, 'Fiber Optic' : 3})

# %%
df.head()
# Out:
#    CustomerID  Gender  Senior_Citizen Partner Dependents  Tenure  \
# 0  0002-ORFBO       0               0     Yes        Yes       9
# 1  0003-MKNFE       1               0      No         No       9
# 2  0004-TLHLJ       1               0      No         No       4
# 3  0011-IGKFF       1               1     Yes         No      13
# 4  0013-EXCHZ       0               1     Yes         No       3
#
#     Service_type Multiple_Lines  Internet_Service_type Online_Security  ...  \
# 0  Phone Service             No                    NaN              No  ...
# 1  Phone Service            Yes                    NaN              No  ...
# 2  Phone Service             No                    NaN              No  ...
# 3  Phone Service             No                    NaN              No  ...
# 4  Phone Service             No                    NaN              No  ...
#
#   Monthly_Charges Total_Charges Number_of_Referrals    Offer  \
# ...

# %%
X.head()
# Out:
#    CustomerID  Gender Partner Dependents  Tenure   Service_type  \
# 0  0002-ORFBO  Female     Yes        Yes       9  Phone Service
# 1  0003-MKNFE    Male      No         No       9  Phone Service
# 2  0004-TLHLJ    Male      No         No       4  Phone Service
# 3  0011-IGKFF    Male     Yes         No      13  Phone Service
# 4  0013-EXCHZ  Female     Yes         No       3  Phone Service
#
#   Internet_Service_type Streaming_TV        Contract    Payment_Method  \
# 0                 Cable          Yes        One Year      Mailed check
# 1                 Cable           No  Month-to-Month      Mailed check
# 2           Fiber Optic           No  Month-to-Month  Electronic check
# 3           Fiber Optic          Yes  Month-to-Month  Electronic check
# 4           Fiber Optic          Yes  Month-to-Month      Mailed check
#
#    Monthly_Charges  Total_Charges  Number_of_Referrals    Offer  \
# 0             65.6         593.30                    2       No
# ...

# %%
data.Gender = data.Gender.map({'Female' : 0, 'Male' : 1})
data.Partner = data.Partner.map({'Yes' : 0, 'No' : 1})
data.Dependents = data.Dependents.map({'Yes' : 0, 'No' : 1})
data.Service_type = data.Service_type.map({'Internet Service' : 0, 'Phone Service' : 1})
data.Internet_Service_type = data.Internet_Service_type.map({'Cable' : 0, 'No' : 1, 'DSL' : 2, 'Fiber Optic' : 3})

# %%
data.Streaming_TV = data.Streaming_TV.map({'No Internet Service' : 'No'})

# %%
data.head()
# Out:
#    CustomerID Gender Partner Dependents  Tenure   Service_type  \
# 0  0002-ORFBO   None     Yes        Yes       9  Phone Service
# 1  0003-MKNFE   None      No         No       9  Phone Service
# 2  0004-TLHLJ   None      No         No       4  Phone Service
# 3  0011-IGKFF   None     Yes         No      13  Phone Service
# 4  0013-EXCHZ   None     Yes         No       3  Phone Service
#
#    Internet_Service_type Streaming_TV        Contract    Payment_Method  \
# 0                    NaN          NaN        One Year      Mailed check
# 1                    NaN          NaN  Month-to-Month      Mailed check
# 2                    NaN          NaN  Month-to-Month  Electronic check
# 3                    NaN          NaN  Month-to-Month  Electronic check
# 4                    NaN          NaN  Month-to-Month      Mailed check
#
#    Monthly_Charges  Total_Charges  Number_of_Referrals    Offer  \
# 0             65.6         593.30                    2       No
# ...
